# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0, 12, 1000)
y = lambda x: x**2
y = y(x)

# %%
plt.plot(x, y)

# %%
x = np.linspace(0, 10, 1000)
y = lambda x: x**3
y = y(x)

# %%
plt.plot(x, y)
